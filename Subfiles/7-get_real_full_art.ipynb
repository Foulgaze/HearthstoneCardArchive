# %%
import json
import requests

# %%
# file_count = 3
with open("../JsonFiles/final_cards.json", "r") as all_cards:
	json_data = json.loads(all_cards.read())
	for card_name in json_data:
		url_to_get = json_data[card_name]['fullArt']
		fixed_url = 
		break
# Out:
# <!DOCTYPE html>
# <html class="client-nojs view-unknown theme-light skin-theme-clientpref-day" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Frothing Berserker - New Hearthstone Wiki</title>
# ...
